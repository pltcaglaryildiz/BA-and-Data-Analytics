# %% [markdown]
# <a href="https://colab.research.google.com/github/pltcaglaryildiz/BA-and-Data-Analytics/blob/main/Baraa_Data_Traininig_Videos_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
== # comparison operator- dogru
# Out:
#   File "/tmp/ipykernel_3538/2578761806.py", line 1
#     == # comparison operator- dogru
#     ^
# SyntaxError: invalid syntax

# %%
% #modulus  - kalan
// #truncated division - bolum
** #exponentiation
# Out:
#   File "/tmp/ipykernel_3538/1351479998.py", line 2
#     // #truncated division
#     ^
# SyntaxError: invalid syntax

# %%
int(3.5) #type ini degistiriyor.
# Out:
# 3

# %%
num= 5//3
print(num)
# Out:
# 1

# %%
sum = 5+3
print(' toplamin sonucu =', sum)
# Out:
#  toplamin sonucu = 8

# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %%
\n # new line
\t #tab boslugu
\b # backspaces
\"     mesaj icinde " kullanmak icin

# %%
print("Hi\n\n\n")
print("nassin?")
## \n kadar bosluk birakarak cevap veriyor.
# Out:
# Hi
#
#
#
# nassin?

# %%
input("enter your message")
# Out:
# enter your message15
# '15'

# %%
name = input("Please enter your name : ")
if name != "Caglar":
  print("Unauthorized user")
else:
  print("Authorized")
# Out:
# Please enter your name : Caglar
# Authorized

# %%
x = "hello nabersin? "
y= "iyi misin?"
## strings can be connected by + operator as well.
x+y
# Out:
# 'hello nabersin? iyi misin?'

# %%
x= "hello nabersin?"
print(len(x)) # len(x) counts the letters
# Out:
# 15

# %%
x.upper() # makes capital all letters
# Out:
# 'HELLO NABERSIN?'

# %%
number = 10
print(number.bit_length()) #returns the lenght in binary
# Out:
# 4

# %%
##COUNT
# it is used to count the words or definet things in string
x= "hello how are you, are you alright or should i call an ambulance?"

print(x.count("a"))
# Out:
# 7

# %%
x = "123144123"
len(x)
## return the number of items in a value
## reteurn the number of characters in a string
# Out:
# 9

# %%
password = "1234abas"
print(len(password))

if len(password) < 10:
    print("Your password is too short")
# Out:
# 8
# Your password is too short

# %%
# count() method
### counts the given value in braclets

text = "python is east to learn, and python is powerful. many people love python"

text.count("python")
# Out:
# 3

# %%
# replace()

#2026/05/10- # we want to chance / with - in date

x = "26/05/10"

x.replace("/","-")
# Out:
# '26-05-10'

# %%
phone = "176-1234-56"
print(phone.replace("-", "/"))

phone = "176-1234-56" ## if we will just replace with nothing, write ""
print(phone.replace("-", ""))
# Out:
# 176/1234/56
# 176123456

# %%
price = "$1,299.99"
print(price.replace("$", "").replace(",","").replace(".",""))
## chained methods are executed in order from left to right. each replace() runs on
#the result of the one before it.
# Out:
# 129999

# %%
##Example Replace Chain##
phone = "+49 (176) 123-4567" ## we want 0049176123467
phone.replace("+", "00").replace("(","").replace(")","").replace("-","").replace(" ","")
# if you wanna remove things like () above, replace it with nothing ---- like this---- "" ---- that is same as removing it.
# Out:
# '00491761234567'

# %%
first_name = "Michael"
last_name = "Scott"

last_name = first_name + " " +  last_name # added 3rd one (space in to addition
print(last_name)
# Out:
# Michael Scott

# %%
folder = "C:/users/caglar"
File  = "report.csv"
full_file_path = folder + "/" + File
print(full_file_path)
# Out:
# C:/users/caglar/report.csv

# %%
## F STRINGS (F stands for formatted)

name = "sam"
age= 34
is_student= False
print ("my name is" + " "+ name + " I am" + " "+  str(age) + " " + "years old and student status is" + " " + str(is_student) + ". ")

print(f"my name is {name} I am {age} years old and student status is {is_student}.")
# Out:
# my name is sam I am 34 years old and student status is False.
# my name is sam I am 34 years old and student status is False.

# %%
## SPLIT
stamp = "2026-09-20"
print (stamp.split("-"))

## split result will give us a list##
# Out:
# ['2026', '09', '20']

# %%
csv_file= "1234,Max,USA,1970-10-05,M"
csv_file.split(",")
# Out:
# ['1234', 'Max', 'USA', '1970-10-05', 'M']

# %%
text = "python"
print(text[1])
#that pulls the letter, counts the P (first letter) as 0.
# Out:
# y

# %%
date = "2026-09-20"
date[0:4]
# Out:
# '2026'

# %%
test =" engineering"
print(test.lstrip()) # lstrip soldaki boslugu siliyor. rstrip de var sagdakini siliyor.
# Out:
# engineering

# %%
## len () method

x= input (password)

if len(x) < 11:
    print("your password is too short, please assign another password longer ")
else:
    print("your password lenght is allright")
# Out:
# 1234a99999999999
# your password lenght is allright

# %%
## Count("") method

x= "python is the best langulage skill in machines. python is usually can be used for everytin. python is easy to learn, but python requires some time to be studied"

print(x.count("python"))

## x.count("words/letters") === by using this, you can count everything in strings i.e .
#ESPECIALY ITS BETTER IN COUNT IN TEXES
# Out:
# 4

# %%
##Transformations -- replace()

x = "2026/05/10"

print(x.replace("/", "")) ### replace("old value", "new value")
# you can even trigger and write chain replace() methods
# Out:
# 20260510

# %%
price= "12345,1231 $"
print(price.replace(",","").replace("$", "£"))
# Out:
# 123451231 £

# %%
## split() method

x= "adam-24-USA"
print(x.split("-"))
# Out:
# ['adam', '24', 'USA']

# %%
stamp= "2026-09-20 14:20"
stamp.split(" ")
#Gun ve saatleri ayirmak icin de kullanilabilir
#splitten sonra sana list veriyor, indexin kullanilabilir sanki?
# Out:
# ['2026-09-20', '14:20']

# %%
x = "nabersin, kanka, her sey yolunda mi?"
x.split(",")
print(x[0:8])
# Out:
# nabersin

# %%
y= "adam-25-USA"
y.split("-") # seperators outputta yer almiyor, oradan split etti
# Out:
# ['adam', '25', 'USA']

# %%
## date time varsa bunlari bolmek icin de kullanabilirsin
stamp= "04/05/2026 01:45"
stamp.split(" ")
# Out:
# ['04/05/2026', '01:45']

# %%
x = "hello"
x[4] + x[0]
# Out:
# 'oh'

# %%
x = "hello"
x[0:3] # starting will bei ncluded, end will not be included.
## [0:4:2] sondaki 2 ise 2 ser atlayarak gidiyor.
# Out:
# 'hel'

# %%
##[START:END:ZIPLAMA]
## [1:]    -- ello - 1 den baslayacak ve devamini alacak.
## [start:end: step] -- kac step atlayarak gidecegini gosteriyor.
x = "hello"
x[0:5:2]
# Out:
# 'hlo'

# %%
x = "hello"
print(x[0],x[4])
# Out:
# h o

# %%
date = "2026-09-20"
date[:4]
# Out:
# '2026'

# %% [markdown]
# # Cleaning Section

# %%
## CLEANING WHITESPACES
x= " MAX" # solda bosluk var.,
x.lstrip() #lstrip = soldaki boslugu aldi, rstrip = sagdaki boslugu aliyor.
## strip==== sag sol ayirmadan hepsini hepsiyor.

y= "   selamlar    "
y.strip()
# Out:
# 'selamlar'

# %%
x = "  max"
print(x.lstrip())
# Out:
# max

# %%
y= "   .selamlar.    ".strip()
print(y) # strip method sadec solda ve sagdakileri siliyor- ortadakileri silmiyor. iki tarafta da varsa...
# Out:
# .selamlar.

# %%
text= "###abc###".strip("#") # bunda da hastagleri siliyor. (parantez icindekileri sildirebilirsin-- illla bosluk olmasina gerek yok )
print(text)
# Out:
# abc

# %%
text = "   engineering "
print("text original", len(text))
print("text stripped" , len(text.strip()))
nr_of_spaces= len(text) - len(text.strip())
print("number of spaces = " ,nr_of_spaces)
is_clean = len(text) == len(text.strip())
print("is my data clean? = ", is_clean)
# Out:
# text original 15
# text stripped 11
# number of spaces =  4
# is my data clean? =  False

# %%
## CLEANING -- CASE CONVERSIONS # # #
# BUYUK HARF VE KUCUK HARF AYARLIYOR##
text= "python PROGRAMMING"
print(text.lower())
# Out:
# python programming

# %%
text= "python PROGRAMMING"
print(text.upper())

#Tum harfleri buyuk harfe ceviriyor#
# Out:
# PYTHON PROGRAMMING

# %%
#### COK SAGLAM ORNEK!! ## TRAININ ICIN IDEAL!

x = "968-Maria, ( D@t@ Engineer ) ;; 27y  "

x = x.strip().replace("@","a").lower().replace(";;",",").replace("968-", "").replace(" ( ", "").replace(" ) ","").replace("y","").split(",")

print(f"name:",  x[0], "| role:",x[1], "| age:", x[2])

### GUZEL ORNEK- AFERIN SAGLAM CHALLENGE
# Out:
# name: maria | role: data engineer | age:  27

# %%
x = "968-Maria, ( D@t@ Engineer ) ;; 27y  "

x.replace("968-"," name: ").replace("@","a").replace(";;","  | age:").replace("y","").replace(" ( ", " | role: ").replace(" ) ", ""). replace(",","").lower()
# Out:
# ' name: maria | role: data engineer  | age: 27  '

# %% [markdown]
# # SEARCHING IN STRINGS

# %%
## startswith()##
## bunun cevabi boolean oluyor- true seklinde

##  endswith() -- bunda da sondan baslayarak check ediyor.

## specific value string icinde araniyorsa ==== bunda da in kullaniyorsun./

#  find("FEB") ## bunda da boleean degil, baslangic harfinin indexini veriyor.

# %%
phone = "+49-176-123345"

phone.startswith("+49")
# Out:
# True

# %%
email = "baraa@hotmail.com"
email.endswith("gmail.com")
# Out:
# False

# %%
file= "data_backup.csv"
file.endswith(".csv")
# Out:
# True

# %%
email = "baraa@hotmail.com"
"@" in email
# Out:
# True

# %%
####COK COK COK ONEMLI BIR ORNEK BU####
####COK COK COK ONEMLI BIR ORNEK BU####
####COK COK COK ONEMLI BIR ORNEK BU####

phone1= "+48-176-12345"
phone2= "48-654-16548"
phone3= "0048-654-165448"
print(phone1[phone1.find("-")+1:])
print(phone2[phone2.find("-")+5:])
## find ile slicing i combineledi, - den sonrasini aldirdi mesela.

# find() gives us index (number) - then  the index casn be used in slicing.
# Out:
# 176-12345
# 16548

# %%
## Validation
country = "USA1"
print(country.isalpha())  ### hepsi string ve harf diye mi bakiyor.
# Out:
# False

# %%
phone= "01764123123"
print(phone.isnumeric())
# Out:
# True

# %% [markdown]
# # NUMERIC OPERATIONS

# %%
x = 3
y= 4

print(complex(x,y))
# Out:
# (3+4j)

# %%
import math

x= 1.6
print(math.floor(x))
print(math.ceil(x))
# Out:
# 1
# 2

# %%
x = 35.34132213
print(round(x,2)) # virgulden sonrasi kac tane hane gosterecegini soyluyor#
# Out:
# 35.34

# %%
import math
x = 35.34132213
print(math.trunc(x)) ## trcun sadec noktadan soldaki tam sayi kismini aliyor ve sana veriyor.
# Out:
# 35

# %%
print(abs(2-10)) # mutlakl degere aliyor
# Out:
# 8

# %%
##Rounding numbers##
import math
price = 313.3124521312
a = math.floor(price)
print(a)

print(math.ceil(price))
# Out:
# 313
# 314

# %%
price = 313.3124521312
print(round(price))
# Out:
# 313

# %%
price = 313.3124521312
print(round(price, 3)) ## round(price, XXX) buradaki xxx shows how many decimals you wanna see.
# Out:
# 313.312

# %%
## Advanced math#
#You have to import the math lib.- sqrt(), sin(),cos(), log() are here. check out the full librar


#https://docs.python.org/3/library/math.html

# %%
import random
random.randint(0,100) ## random.randint(a,b) includes a and b for the randoming interval- includes both ab
# Out:
# 16

# %%
##  Random number generator Game# #

import random
y = random.randint(0,10)
x = input("Guess a number in between 0 and 10   "  )

if x == y:
  print("You are correct")
else:
  print("You did not know LOL, the correct number was:  ", y)
# Out:
# Guess a number in between 0 and 10   8
# You did not know LOL, the correct number was:   6

# %% [markdown]
# #CONROL FLOW SECTION- LOOPS CONDITIONALS AND CONTROLS

# %%
## build questions like booleans so that python checks and continue##

#1- values and function
print(True)
print(False)
print(type(True))
print(bool(123)) # bool() icinde deger varsa TRUE, ici bos ise False degeri alacak.
# Out:
# True
# False
# <class 'bool'>
# True

# %%
email = ""
phone= " 0176-65465-264"
username = ""

print(any([email,phone,username])) # any needs any one of them is fulfilled
print(all([email,phone,username])) #  all needs everyone of them fulfilled
# Out:
# True
# False

# %%
 #comparison operators
 #    >,  < , >= ,  <= , == , !=
